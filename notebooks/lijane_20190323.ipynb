# %%
#import packages pandas, numpy, nltk
#goals: want to conduct a sentiment analysis of drug reviews
#for newbies: https://www.tutorialspoint.com/python/python_text_processing_environment.htm

# %%
import pandas as pd
import numpy as np

# %%
import nltk

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is ACE3-2CE5
#
#  Directory of C:\Users\janes\Untitled Folder
#
# 03/23/2019  12:35 PM    <DIR>          .
# 03/23/2019  12:35 PM    <DIR>          ..
# 03/23/2019  12:31 PM    <DIR>          .ipynb_checkpoints
# 03/23/2019  12:34 PM                22 drugsCom_raw.zip
# 03/23/2019  12:34 PM        28,071,166 drugsComTest_raw.tsv
# 03/23/2019  12:34 PM        84,289,175 drugsComTrain_raw.tsv
# 03/23/2019  12:35 PM               717 Untitled.ipynb
#                4 File(s)    112,361,080 bytes
#                3 Dir(s)  53,420,040,192 bytes free

# %%
df = pd.read_csv('drugsComTrain_raw.tsv', sep = '\t')

# %%
df
# Out:
#         Unnamed: 0                            drugName  \
# 0           206461                           Valsartan
# 1            95260                          Guanfacine
# 2            92703                              Lybrel
# 3           138000                          Ortho Evra
# 4            35696            Buprenorphine / naloxone
# 5           155963                              Cialis
# 6           165907                      Levonorgestrel
# 7           102654                        Aripiprazole
# 8            74811                              Keppra
# 9            48928  Ethinyl estradiol / levonorgestrel
# 10           29607                          Topiramate
# 11           75612                      L-methylfolate
# 12          191290                             Pentasa
# 13          221320                    Dextromethorphan
# 14           98494                           Nexplanon
# 15           81890                         Liraglutide
# ...

# %%
#following tutorial in link at beginning
#python string immutability: cannot update string value

# %%
#Can not reassign
t = "Tutorialspoint"
print(type(t))
t[0] = "M"
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4098d797087c> in <module>
#       2 t = "Tutorialspoint"
#       3 print(type(t))
# ----> 4 t[0] = "M"
#
# TypeError: 'str' object does not support item assignment

# %%
#Check the memory location address of the position of letters of the string

x = 'banana'
for idx in range(0,5):
        print(x[idx], "=", id(x[idx]))
# Out:
# b = 2379682583024
# a = 2379682584704
# n = 2379682453688
# a = 2379682584704
# n = 2379682453688

# %%
#'a' and 'a' point to same location, as well as the two 'n's

# %%
#put your data into a pandas dataframe and checkout some characteristics

# %%
df_working = pd.DataFrame(data=df)

# %%
size of the dataframe

# %%
print(df_working.shape)
# Out:
# (161297, 7)

# %%
print(len(df_working.index))
# Out:
# 161297

# %%
#the columns, covariates of the dataframe

# %%
list(df_working.columns.values)
# Out:
# ['Unnamed: 0',
#  'drugName',
#  'condition',
#  'review',
#  'rating',
#  'date',
#  'usefulCount']

# %%
df_working.sort_values('drugName')
# Out:
#         Unnamed: 0                              drugName  \
# 9892        163935             A + D Cracked Skin Relief
# 18402       131173                            A / B Otic
# 67773        70690  Abacavir / dolutegravir / lamivudine
# 68300        70730  Abacavir / dolutegravir / lamivudine
# 137301       70740  Abacavir / dolutegravir / lamivudine
# 10591        70723  Abacavir / dolutegravir / lamivudine
# 65294        70743  Abacavir / dolutegravir / lamivudine
# 82743        70681  Abacavir / dolutegravir / lamivudine
# 59740        70709  Abacavir / dolutegravir / lamivudine
# 91907        70710  Abacavir / dolutegravir / lamivudine
# 103845       70731  Abacavir / dolutegravir / lamivudine
# 106530       70686  Abacavir / dolutegravir / lamivudine
# 110898       70735  Abacavir / dolutegravir / lamivudine
# 144867       70695  Abacavir / dolutegravir / lamivudine
# 96360        70714  Abacavir / dolutegravir / lamivudine
# ...

# %%
df_working['drugName'].value_counts()
# Out:
# Levonorgestrel                        3657
# Etonogestrel                          3336
# Ethinyl estradiol / norethindrone     2850
# Nexplanon                             2156
# Ethinyl estradiol / norgestimate      2117
# Ethinyl estradiol / levonorgestrel    1888
# Phentermine                           1543
# Sertraline                            1360
# Escitalopram                          1292
# Mirena                                1242
# Implanon                              1102
# Gabapentin                            1047
# Bupropion                             1022
# Venlafaxine                           1016
# Miconazole                            1000
# Medroxyprogesterone                    995
# Citalopram                             995
# Lexapro                                952
# Bupropion / naltrexone                 950
# Duloxetine                             934
# Metronidazole                          922
# Contrave                               920
# ...
